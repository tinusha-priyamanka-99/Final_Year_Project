# %%
import openai
import pandas as pd

with open('API_2.txt') as file:
    openai.api_key = file.read()

def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def ask_gpt3(question, context):
    prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"
    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ],
    max_tokens= 250,
    )
    answer = response['choices'][0]['message']['content'].strip()
    return answer

file_context = ['JD_1.txt']

for file in file_context:
    context = read_text_file(file)

    prompts = [
        "Mention the job title using less than four words.",
        "Mention the number of experience years needed for positions using less than six words.",
        "Mention the specified degrees and academic qualifications using minimum number of words.",
    ]

    job_titles = []
    experienced_years = []
    academic_qualifications = []



    for prompt in prompts:
        answer = ask_gpt3(prompt, context)
        answer = answer.split('\n')

        index = prompts.index(prompt)
        if index == 0:
            job_titles.append(answer)
        elif index == 1:
            experienced_years.append(answer)
        elif index == 2:
            academic_qualifications.append(answer)



    data = {
        "Job title": job_titles,
        "Experienced years": experienced_years,
        "Academic Qualification": academic_qualifications
    }

    df = pd.DataFrame(data)

    print(df)
    
    excel_file_path = "output_api.xlsx"
    df.to_excel(excel_file_path, index=False)
    print(f"Excel file saved successfully at: {excel_file_path}")
# Out:
#                        Job title                    Experienced years  \
# 0  [Sustainable Finance Analyst]  [1-2 years of relevant experience.]
#
#                               Academic Qualification
# 0  [Degree in science/business/accounting or prof...
# Excel file saved successfully at: output_api.xlsx

# %%
import pandas as pd
import openai

# Assuming the openai.api_key is set up already

def read_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    return text

def ask_gpt3(question, context):
    prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"
    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ],
        max_tokens=250,
    )
    answer = response['choices'][0]['message']['content'].strip()
    return answer

file_context = ['JD_1.txt','JD_2.txt','JD_3.txt','JD_4.txt','JD_5.txt']

output_data = []

for file in file_context:
    context = read_text_file(file)

    prompts = [
        "Mention the job title using less than four words.",
        "Mention the number of experience years needed for positions using less than six words.",
        "Mention the specified degrees and academic qualifications using minimum number of words.",
    ]

    job_titles = []
    experienced_years = []
    academic_qualifications = []

    for prompt in prompts:
        answer = ask_gpt3(prompt, context)
        answer = answer.split('\n')

        index = prompts.index(prompt)
        if index == 0:
            job_titles.append(answer)
        elif index == 1:
            experienced_years.append(answer)
        elif index == 2:
            academic_qualifications.append(answer)

    output_data.append({
        "File": file,
        "Job title": job_titles,
        "Experienced years": experienced_years,
        "Academic Qualification": academic_qualifications
    })

# Combine all data into a single DataFrame
final_df = pd.DataFrame(output_data)

# Write the DataFrame to an Excel file
excel_file_path = "output.xlsx"
final_df.to_excel(excel_file_path, index=False)

print(f"Excel file saved successfully at: {excel_file_path}")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 43
#      40 academic_qualifications = []
#      42 for prompt in prompts:
# ---> 43     answer = ask_gpt3(prompt, context)
#      44     answer = answer.split('\n')
#      46     index = prompts.index(prompt)
#
# Cell In[4], line 14, in ask_gpt3(question, context)
#      11 def ask_gpt3(question, context):
#      12     prompt = f"Context: {context}\nQuestion: {question}\nAnswer:"
# ---> 14     response = openai.ChatCompletion.create(
#      15         model="gpt-3.5-turbo",
#      16         messages=[
#      17             {"role": "system", "content": "You are a helpful assistant."},
#      18             {"role": "user", "content": prompt},
#      19         ],
#      20         max_tokens=250,
#      21     )
#      22     answer = response['choices'][0]['message']['content'].strip()
# ...
